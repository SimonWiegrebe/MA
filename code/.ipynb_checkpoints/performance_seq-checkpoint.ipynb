# %%
import datetime
import matplotlib
import numpy as np
import pandas as pd
import pyreadr

import os

# %%
USER_KEY = 'userID'
TIME_KEY = 'timestamp'
ITEM_KEY = 'usID'
SESSION_KEY = 'sentenceID'

# %%
path_results = '../results/sequence-level/single/drop_seq_onoff_all/untuned/'
# path_results = '../results/drop_on/untuned/'
# path_results = '../results/drop_on-drop_off/untuned/'

test_data = pd.read_hdf('../../data/sequence-level/single/' + 'events-seq_drop_onoff_all.hdf', 'test') # make sure this aligns with path_results

# %%
results_files = [f for f in os.listdir(path_results) if 'Saver' not in f]
results = pd.DataFrame()
for file in results_files:
    df = pd.read_csv(path_results + file, sep = ';')
    # TBD: extract window number from file name, create new column
    df.drop(['Metrics', 'Saver@50: '], axis=1, inplace=True)
    df.drop(df.filter(regex='Unnamed'), axis=1, inplace=True) # drop 'Unnamed: 24' column containing only NaNs
    df.rename(columns = lambda x : str(x)[:-2], inplace=True) # remove colon and whitespace from all column names
    df.insert(0, 'model', "_".join(file.split('_')[2:-1]))
    results = results.append(df)

# %%
results
# Out:
#               model  MAP@1     MAP@5    MAP@10    MAP@20  Precision@1  \
# 0                ar    0.0  0.042510  0.048198  0.040999     0.673187
# 0  gru4rec_Reminder    0.0  0.030177  0.026259  0.019471     0.604391
# 0           gru4rec    0.0  0.016078  0.012596  0.009472     0.437126
# 0          hgru4rec    0.0  0.008647  0.006637  0.004828     0.288224
# 0              shan    0.0  0.033481  0.038984  0.034781     0.506853
# 0              sknn    0.0  0.041143  0.048763  0.042232     0.607319
# 0             sr_BR    0.0  0.043797  0.043158  0.036842     0.675449
# 0                sr    0.0  0.041139  0.044458  0.037711     0.647372
# 0           stan_ER    0.0  0.045085  0.047039  0.039358     0.659747
# 0              stan    0.0  0.039370  0.045066  0.041294     0.632069
# 0         vsknn_EBR    0.0  0.018707  0.023182  0.023503     0.282102
# 0             vsknn    0.0  0.009494  0.009351  0.008355     0.233001
# 0         vstan_EBR    0.0  0.016227  0.017875  0.018819     0.298869
# 0             vstan    0.0  0.040181  0.046506  0.039473     0.636727
#
#    Precision@5  Precision@10  Precision@20  Recall@1  ...  HitRate@1  \
# 0     0.492854      0.380998      0.256228  0.049665  ...   0.199468
# 0     0.340040      0.236327      0.150559  0.049141  ...   0.242315
# 0     0.197977      0.134185      0.089760  0.034864  ...   0.180971
# 0     0.116327      0.078164      0.052402  0.023474  ...   0.118563
# 0     0.426241      0.338736      0.231317  0.035195  ...   0.084498
# 0     0.483220      0.383606      0.258596  0.041398  ...   0.151564
# 0     0.478270      0.350752      0.241351  0.052668  ...   0.253626
# 0     0.464857      0.356846      0.240852  0.051940  ...   0.254824
# 0     0.499774      0.373666      0.251457  0.048690  ...   0.200798
# 0     0.461770      0.369182      0.257332  0.045875  ...   0.190951
# 0     0.276460      0.245549      0.189042  0.018564  ...   0.059880
# 0     0.157552      0.120812      0.090439  0.013614  ...   0.048969
# 0     0.242422      0.201544      0.159654  0.020733  ...   0.083699
# 0     0.463792      0.372322      0.248769  0.047809  ...   0.206919
#
#    HitRate@5  HitRate@10  HitRate@20     MRR@1     MRR@5    MRR@10    MRR@20  \
# 0   0.442848    0.556620    0.640985  0.199468  0.290044  0.305256  0.311093
# 0   0.446840    0.514305    0.579242  0.242315  0.318858  0.328182  0.332805
# 0   0.317764    0.385496    0.451364  0.180971  0.230659  0.239787  0.244440
# 0   0.193746    0.246840    0.304458  0.118563  0.145509  0.152504  0.156411
# 0   0.316168    0.443779    0.554624  0.084498  0.168973  0.185997  0.193778
# 0   0.415037    0.534664    0.626347  0.151564  0.248337  0.264442  0.270941
# 0   0.484897    0.556620    0.636860  0.253626  0.342191  0.351794  0.357297
# 0   0.495941    0.582701    0.664138  0.254824  0.344624  0.356168  0.361811
# 0   0.452428    0.549568    0.627279  0.200798  0.293626  0.306638  0.312042
# 0   0.440585    0.553826    0.642582  0.190951  0.282220  0.297514  0.303878
# 0   0.178576    0.265735    0.368064  0.059880  0.100268  0.111847  0.118871
# 0   0.113506    0.151297    0.195875  0.048969  0.071859  0.076864  0.079974
# 0   0.177645    0.236460    0.315502  0.083699  0.117121  0.124791  0.130236
# 0   0.455356    0.564471    0.644711  0.206919  0.297740  0.312512  0.318161
#
#    Coverage@20  Popularity@20
# 0     0.209408       0.254571
# 0     0.645524       0.085802
# 0     0.957815       0.040294
# 0     0.834901       0.018805
# 0     0.021548       0.219715
# 0     0.239150       0.220649
# 0     0.467678       0.177414
# 0     0.648558       0.230743
# 0     0.438847       0.180978
# 0     0.384825       0.234746
# 0     0.207284       0.100016
# 0     0.529590       0.025712
# 0     0.505615       0.059163
# 0     0.502883       0.230721
#
# [14 rows x 23 columns]

# %% [markdown]
# ### extracting predictions

# %%
# create app and user mappings
data = pd.read_csv('../../data/sequence-level/data_seq.csv')

mapping = dict([(y,x+1) for x,y in enumerate(sorted(set(data['category_list'])))])
mapping_reverse = dict((v,k) for k,v in mapping.items())

# %%
# extract ground truth from test data (test_data) for a single item (position) in a single session (sessionId)
def extract_ground_truth(ID, position, test_data):
    relevant_df = test_data[test_data[SESSION_KEY]==ID]
    index = relevant_df.index[position+1]
    ground_truth = relevant_df[ITEM_KEY][index]
    return ground_truth

# %%
predictions_files = [f for f in os.listdir(path_results) if 'Saver' in f]
predictions = pd.DataFrame()
for file in predictions_files:
    model = "_".join(file.split('_')[2:-1])
    df = pd.read_csv(path_results + file, sep = ';')
    if 'sessionID' not in predictions.columns:
        predictions['sessionID'] = df['SessionId']
    if 'position' not in predictions.columns:
        predictions['position'] = df['Position']
    if 'ground_truth' not in predictions.columns:
        predictions['ground_truth'] = predictions.apply(lambda x: extract_ground_truth(x['sessionID'], x['position'], test_data), axis=1)
        predictions['ground_truth_name'] = predictions['ground_truth'].apply(lambda x: mapping_reverse[x])
    predictions['recs-' + model] = df['Recommendations'].apply(lambda x: [int(i) for i in x.split(',')])
    predictions['recs_names-' + model] = predictions['recs-' + model].apply(lambda x: [mapping_reverse[i] for i in x])
    predictions['scores-' + model] = df['Scores'].apply(lambda x: x.split(','))

# %%
def print_predictions(predictions, sessionID, num_recs, models):
    # predictions must contain columns named 'sessionID' and 'position', containing the respective values
    predictions_dict = {}
    for pos in positions:
        row = predictions[(predictions.sessionID == sessionID) & (predictions.position == pos)]
        ground_truth = row.ground_truth_name.to_string(index=False)
#         print('sessionID: ' + str(sessionID) + ', position: ' + str(pos))
#         print('ground truth: ' + str(row.ground_truth_name.to_string(index=False)))
        df = pd.DataFrame()
        for model in models:
            df[model] = [row['recs_names-' + model].tolist()[0][i] for i in range(num_recs)]
        name = str(sessionID) + '_' + str(pos)
        predictions_dict[name] = (sessionID, pos, ground_truth, df)
    return predictions_dict

# %%
sessionID = predictions.sessionID.unique()[0]
num_recs = 5
positions = predictions.position[predictions.sessionID==sessionID]
models = results.model.tolist()

# %%
print_predictions(predictions, sessionID, num_recs, models)
# Out:
# {'27_0': (27,
#   0,
#   'ON,Launcher,Orientation,Launcher,Financial,Laun...',
#                                                     ar  \
#   0  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   1  ON,Launcher,Messaging,Launcher,TVVideo_Apps,La...
#   2  ON,Launcher,Social_Networks,Launcher,Settings,...
#   3  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   4  ON,Launcher,ON,Messaging,Timer_Clocks,Messagin...
#
#                                       gru4rec_Reminder  \
#   0  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   1  ON,Launcher,Messaging,Launcher,TVVideo_Apps,La...
#   2  ON,Music_Audio_Radio,PLAY,Launcher,Messaging,L...
#   3  ON,Launcher,ON,Messaging,Launcher,Social_Netwo...
#   4  ON,Music_Audio_Radio,PAUSE,PLAY,PAUSE,PLAY,Lau...
#
#                                                gru4rec  \
#   0  ON,Music_Audio_Radio,PLAY,Launcher,Messaging,L...
#   1  ON,Launcher,ON,Messaging,Launcher,Social_Netwo...
#   2  ON,Financial,ON,Financial,Launcher,Messaging,L...
#   3  ON,Launcher,ON,Messaging,Launcher,Social_Netwo...
#   4  ON,Music_Audio_Radio,PLAY,PAUSE,Music_Audio_Ra...
#
#                                               hgru4rec  \
#   0  ON,Financial,ON,Financial,Launcher,Messaging,L...
#   1  ON,Music_Audio_Radio,PLAY,Launcher,Messaging,L...
#   2  ON,Internet_Browser,Social_Networks,Internet_B...
#   3  ON,Music_Audio_Radio,PLAY,PAUSE,PLAY,PAUSE,PLA...
#   4  ON,Launcher,ON,E_Mail,Launcher,Gaming_Casual,L...
#
#                                                   shan  \
#   0  ON,Gaming_Simulation,Launcher,Messaging,Launch...
#   1          ON,Camera,VIDEO,Launcher,ON,Messaging,OFF
#   2  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   3  ON,Betting_Risk,Launcher,Betting_Risk,Launcher...
#   4  ON,Launcher,Messaging,Launcher,Social_Networks...
#
#                                                   sknn  \
#   0  ON,Launcher,ON,Messaging,Launcher,Social_Netwo...
#   1  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   2  ON,Launcher,Messaging,Launcher,TVVideo_Apps,La...
#   3  ON,Launcher,Social_Networks,Launcher,Settings,...
#   4  ON,Launcher,Messaging,Launcher,Social_Networks...
#
#                                                  sr_BR  \
#   0  ON,Launcher,Messaging,Launcher,TVVideo_Apps,La...
#   1  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   2  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   3  ON,Launcher,Timer_Clocks,Launcher,Shop_Sell_Re...
#   4  ON,Launcher,ON,Messaging,Launcher,Messaging,La...
#
#                                                     sr  \
#   0  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   1  ON,Launcher,Messaging,Launcher,TVVideo_Apps,La...
#   2  ON,Launcher,Social_Networks,Launcher,Settings,...
#   3  ON,Launcher,Messaging,Launcher,Social_Networks...
#   4  ON,Launcher,ON,Messaging,Timer_Clocks,Messagin...
#
#                                                stan_ER  \
#   0  ON,Launcher,ON,Messaging,Launcher,Social_Netwo...
#   1  ON,Launcher,Timer_Clocks,Launcher,Shop_Sell_Re...
#   2  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   3  ON,Launcher,Messaging,Launcher,TVVideo_Apps,La...
#   4  ON,Launcher,ON,Messaging,Launcher,Messaging,La...
#
#                                                   stan  \
#   0  ON,Launcher,ON,Messaging,Launcher,Social_Netwo...
#   1  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   2  ON,Launcher,Social_Networks,Launcher,Settings,...
#   3          ON,Camera,VIDEO,Launcher,ON,Messaging,OFF
#   4  ON,Music_Audio_Radio,PLAY,Launcher,Messaging,L...
#
#                                              vsknn_EBR  \
#   0          ON,Camera,VIDEO,Launcher,ON,Messaging,OFF
#   1  ON,Betting_Risk,Launcher,Betting_Risk,Launcher...
#   2  ON,Launcher,ON,Messaging,Social_Networks,Launc...
#   3  ON,Launcher,Internet_Browser,Sharing_Cloud,Int...
#   4  ON,PAUSE,PLAY,PAUSE,PLAY,PAUSE,PLAY,PAUSE,PLAY...
#
#                                                  vsknn  \
#   0  ON,Launcher,ON,Messaging,Launcher,Social_Netwo...
#   1  ON,Music_Audio_Radio,Messaging,Launcher,Social...
#   2  ON,Launcher,ON,TVVideo_Apps,Launcher,Timer_Clo...
#   3  ON,Launcher,ON,Social_Networks,Launcher,TVVide...
#   4  ON,Messaging,ON,Social_Networks,Launcher,Socia...
#
#                                              vstan_EBR  \
#   0  ON,Launcher,ON,Messaging,Launcher,Social_Netwo...
#   1  ON,Launcher,Timer_Clocks,Launcher,Shop_Sell_Re...
#   2  ON,Launcher,ON,Messaging,Launcher,Messaging,La...
#   3  ON,Launcher,Messaging,Launcher,TVVideo_Apps,La...
#   4  ON,Music_Audio_Radio,PLAY,Launcher,Messaging,L...
#
#                                                  vstan
#   0  ON,Launcher,ON,Messaging,Launcher,Social_Netwo...
#   1  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   2  ON,Launcher,Social_Networks,Launcher,Settings,...
#   3          ON,Camera,VIDEO,Launcher,ON,Messaging,OFF
#   4  ON,Launcher,Messaging,Launcher,TVVideo_Apps,La...  ),
#  '27_1': (27,
#   1,
#   'ON,Launcher,Orientation,Launcher,Financial,Laun...',
#                                                     ar  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   2  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   3  ON,Launcher,Social_Networks,Launcher,Settings,...
#   4  ON,Orientation,ON,Launcher,Timer_Clocks,Launch...
#
#                                       gru4rec_Reminder  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Launcher,Social_Networks,Launcher,Settings,...
#   2  ON,Messaging,Launcher,Calling,Launcher,Messagi...
#   3  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   4  ON,Messaging,ON,Messaging,Camera,Launcher,Came...
#
#                                                gru4rec  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   2  ON,Launcher,Social_Networks,Launcher,Settings,...
#   3  ON,Messaging,Launcher,Messaging,Launcher,Healt...
#   4  ON,Launcher,TVVideo_Apps,Internet_Browser,Laun...
#
#                                               hgru4rec  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1          ON,Launcher,TVVideo_Apps,DISCONNECTED,OFF
#   2  ON,Messaging,Launcher,Messaging,Launcher,Note_...
#   3  ON,Launcher,System_App,Messaging,Launcher,E_Ma...
#   4  ON,Launcher,Shared_Transportation,Launcher,Int...
#
#                                                   shan  \
#   0  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   1  ON,Launcher,Messaging,Launcher,Social_Networks...
#   2  ON,Launcher,Social_Networks,Launcher,Settings,...
#   3          ON,Camera,VIDEO,Launcher,ON,Messaging,OFF
#   4  ON,Launcher,Messaging,Launcher,TVVideo_Apps,La...
#
#                                                   sknn  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   2  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   3  ON,Launcher,ON,Messaging,Launcher,Social_Netwo...
#   4  ON,Launcher,Messaging,Launcher,Social_Networks...
#
#                                                  sr_BR  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Launcher,Messaging,Launcher,TVVideo_Apps,La...
#   2  ON,Launcher,Timer_Clocks,Launcher,Shop_Sell_Re...
#   3  ON,Launcher,ON,Messaging,Launcher,Messaging,La...
#   4  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#
#                                                     sr  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   2  ON,Launcher,Social_Networks,Launcher,Settings,...
#   3  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   4  ON,Messaging,Launcher,ON,Launcher,Calendar_App...
#
#                                                stan_ER  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Launcher,Messaging,Launcher,TVVideo_Apps,La...
#   2  ON,Launcher,Timer_Clocks,Launcher,Shop_Sell_Re...
#   3  ON,Gaming_Simulation,Launcher,Messaging,Launch...
#   4  ON,Launcher,ON,Messaging,Launcher,Messaging,La...
#
#                                                   stan  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   2  ON,Launcher,ON,Messaging,Launcher,Social_Netwo...
#   3  ON,Launcher,Social_Networks,Launcher,Settings,...
#   4  ON,Launcher,Messaging,Launcher,Social_Networks...
#
#                                              vsknn_EBR  \
#   0          ON,Camera,VIDEO,Launcher,ON,Messaging,OFF
#   1  ON,Betting_Risk,Launcher,Betting_Risk,Launcher...
#   2  ON,Launcher,Internet_Browser,Sharing_Cloud,Int...
#   3  ON,Launcher,ON,Messaging,Social_Networks,Launc...
#   4  ON,Messaging,Launcher,Calling,Launcher,Messagi...
#
#                                                  vsknn  \
#   0  ON,Messaging,ON,Messaging,Camera,Launcher,Came...
#   1  ON,Settings,ON,Settings,Launcher,Settings,Laun...
#   2  ON,Launcher,ON,Messaging,Launcher,Social_Netwo...
#   3  ON,Internet_Browser,Launcher,Messaging,E_Mail,...
#   4  ON,Messaging,ON,Messaging,Internet_Browser,Lau...
#
#                                              vstan_EBR  \
#   0  ON,Launcher,ON,Messaging,Launcher,Social_Netwo...
#   1  ON,Launcher,Tools,Internet_Browser,Launcher,He...
#   2  ON,Launcher,Timer_Clocks,Launcher,Shop_Sell_Re...
#   3  ON,Internet_Browser,Launcher,Messaging,E_Mail,...
#   4                    ON,Launcher,Travel,Launcher,OFF
#
#                                                  vstan
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   2  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   3  ON,Launcher,Social_Networks,Launcher,Settings,...
#   4  ON,Launcher,Messaging,Launcher,Social_Networks...  ),
#  '27_2': (27,
#   2,
#   'ON,Launcher,Orientation,Launcher,Financial,Laun...',
#                                                     ar  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   2  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   3  ON,Launcher,Social_Networks,Launcher,Settings,...
#   4  ON,Orientation,ON,Launcher,Timer_Clocks,Launch...
#
#                                       gru4rec_Reminder  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Messaging,ON,Messaging,Camera,Launcher,Came...
#   2  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   3  ON,Launcher,Social_Networks,Launcher,Settings,...
#   4  ON,Messaging,Launcher,Calling,Launcher,Messagi...
#
#                                                gru4rec  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Launcher,Social_Networks,Launcher,Settings,...
#   2  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   3  ON,Messaging,ON,Internet_Browser,Shopping,Eati...
#   4  ON,Messaging,ON,Launcher,Financial,Launcher,Me...
#
#                                               hgru4rec  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Messaging,Launcher,Messaging,Launcher,Note_...
#   2          ON,Launcher,TVVideo_Apps,DISCONNECTED,OFF
#   3  ON,Launcher,Shared_Transportation,Launcher,Int...
#   4  ON,Messaging,ON,Messaging,Internet_Browser,Lau...
#
#                                                   shan  \
#   0  ON,Gaming_Simulation,Launcher,Messaging,Launch...
#   1          ON,Camera,VIDEO,Launcher,ON,Messaging,OFF
#   2  ON,Orientation,ON,Launcher,Timer_Clocks,Launch...
#   3  ON,Betting_Risk,Launcher,Betting_Risk,Launcher...
#   4  ON,Launcher,Orientation,Launcher,Financial,Lau...
#
#                                                   sknn  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   2  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   3  ON,Launcher,ON,Messaging,Launcher,Social_Netwo...
#   4  ON,Launcher,Messaging,Launcher,Social_Networks...
#
#                                                  sr_BR  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Launcher,Messaging,Launcher,TVVideo_Apps,La...
#   2  ON,Launcher,Timer_Clocks,Launcher,Shop_Sell_Re...
#   3  ON,Launcher,ON,Messaging,Launcher,Messaging,La...
#   4  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#
#                                                     sr  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   2  ON,Launcher,Social_Networks,Launcher,Settings,...
#   3  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   4  ON,Messaging,Launcher,ON,Launcher,Calendar_App...
#
#                                                stan_ER  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Launcher,Messaging,Launcher,TVVideo_Apps,La...
#   2  ON,Launcher,Timer_Clocks,Launcher,Shop_Sell_Re...
#   3  ON,Gaming_Simulation,Launcher,Messaging,Launch...
#   4  ON,Launcher,ON,Messaging,Launcher,Messaging,La...
#
#                                                   stan  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   2  ON,Launcher,Social_Networks,Launcher,Settings,...
#   3  ON,Launcher,Messaging,Launcher,Social_Networks...
#   4  ON,Launcher,ON,Messaging,Launcher,Social_Netwo...
#
#                                              vsknn_EBR  \
#   0          ON,Camera,VIDEO,Launcher,ON,Messaging,OFF
#   1  ON,Betting_Risk,Launcher,Betting_Risk,Launcher...
#   2  ON,Launcher,Internet_Browser,Sharing_Cloud,Int...
#   3  ON,Launcher,ON,Messaging,Social_Networks,Launc...
#   4  ON,Messaging,Launcher,Calling,Launcher,Messagi...
#
#                                                  vsknn  \
#   0  ON,Messaging,ON,Messaging,Camera,Launcher,Came...
#   1  ON,Settings,ON,Settings,Launcher,Settings,Laun...
#   2  ON,Internet_Browser,Launcher,Messaging,E_Mail,...
#   3  ON,Messaging,ON,Messaging,Internet_Browser,Lau...
#   4  ON,Launcher,ON,Messaging,Launcher,Social_Netwo...
#
#                                              vstan_EBR  \
#   0  ON,Launcher,Tools,Internet_Browser,Launcher,He...
#   1  ON,Launcher,ON,Messaging,Launcher,Social_Netwo...
#   2  ON,Launcher,Timer_Clocks,Launcher,Shop_Sell_Re...
#   3  ON,Internet_Browser,Launcher,Messaging,E_Mail,...
#   4                    ON,Launcher,Travel,Launcher,OFF
#
#                                                  vstan
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   2  ON,Launcher,Social_Networks,Launcher,Settings,...
#   3  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   4  ON,Launcher,Messaging,Launcher,Social_Networks...  ),
#  '27_3': (27,
#   3,
#   'ON,Camera,VIDEO,Launcher,ON,Messaging,OFF',
#                                                     ar  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   2  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   3  ON,Launcher,Social_Networks,Launcher,Settings,...
#   4  ON,Orientation,ON,Launcher,Timer_Clocks,Launch...
#
#                                       gru4rec_Reminder  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Messaging,ON,Messaging,Camera,Launcher,Came...
#   2  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   3  ON,Messaging,ON,Messaging,Internet_Browser,Lau...
#   4  ON,Messaging,Launcher,Calling,Launcher,Messagi...
#
#                                                gru4rec  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Messaging,ON,Internet_Browser,Shopping,Eati...
#   2  ON,Launcher,TVVideo_Apps,Launcher,Social_Netwo...
#   3  ON,Messaging,Launcher,Music_Audio_Radio,Launch...
#   4  ON,Launcher,Social_Networks,Messaging,Internet...
#
#                                               hgru4rec  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Messaging,Launcher,Messaging,Launcher,Note_...
#   2          ON,Launcher,TVVideo_Apps,DISCONNECTED,OFF
#   3  ON,Launcher,Shared_Transportation,Launcher,Int...
#   4  ON,Messaging,ON,Messaging,Internet_Browser,Lau...
#
#                                                   shan  \
#   0  ON,Gaming_Simulation,Launcher,Messaging,Launch...
#   1  ON,Orientation,ON,Launcher,Timer_Clocks,Launch...
#   2  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   3  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   4          ON,Camera,VIDEO,Launcher,ON,Messaging,OFF
#
#                                                   sknn  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   2  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   3  ON,Launcher,ON,Messaging,Launcher,Social_Netwo...
#   4  ON,Launcher,Messaging,Launcher,Social_Networks...
#
#                                                  sr_BR  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Launcher,Messaging,Launcher,TVVideo_Apps,La...
#   2  ON,Launcher,Timer_Clocks,Launcher,Shop_Sell_Re...
#   3  ON,Launcher,ON,Messaging,Launcher,Messaging,La...
#   4  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#
#                                                     sr  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   2  ON,Launcher,Social_Networks,Launcher,Settings,...
#   3  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   4  ON,Messaging,Launcher,ON,Launcher,Calendar_App...
#
#                                                stan_ER  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Launcher,Messaging,Launcher,TVVideo_Apps,La...
#   2  ON,Launcher,Timer_Clocks,Launcher,Shop_Sell_Re...
#   3  ON,Gaming_Simulation,Launcher,Messaging,Launch...
#   4  ON,Launcher,ON,Messaging,Launcher,Messaging,La...
#
#                                                   stan  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   2  ON,Launcher,Social_Networks,Launcher,Settings,...
#   3  ON,Launcher,Messaging,Launcher,Social_Networks...
#   4  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#
#                                              vsknn_EBR  \
#   0          ON,Camera,VIDEO,Launcher,ON,Messaging,OFF
#   1  ON,Betting_Risk,Launcher,Betting_Risk,Launcher...
#   2  ON,Launcher,Internet_Browser,Sharing_Cloud,Int...
#   3  ON,Launcher,ON,Messaging,Social_Networks,Launc...
#   4  ON,Messaging,Launcher,Calling,Launcher,Messagi...
#
#                                                  vsknn  \
#   0  ON,Messaging,ON,Messaging,Camera,Launcher,Came...
#   1  ON,Settings,ON,Settings,Launcher,Settings,Laun...
#   2  ON,Internet_Browser,Launcher,Messaging,E_Mail,...
#   3  ON,Messaging,ON,Messaging,Internet_Browser,Lau...
#   4  ON,Launcher,ON,Messaging,Launcher,Social_Netwo...
#
#                                              vstan_EBR  \
#   0  ON,Launcher,Tools,Internet_Browser,Launcher,He...
#   1                    ON,Launcher,Travel,Launcher,OFF
#   2  ON,Betting_Risk,Launcher,Betting_Risk,Launcher...
#   3  ON,Launcher,Timer_Clocks,Launcher,Shop_Sell_Re...
#   4  ON,Internet_Browser,Launcher,Messaging,E_Mail,...
#
#                                                  vstan
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   2  ON,Launcher,Social_Networks,Launcher,Settings,...
#   3  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   4  ON,Launcher,Messaging,Launcher,Social_Networks...  ),
#  '27_4': (27,
#   4,
#   'ON,Launcher,ON,Messaging,Launcher,Settings,Laun...',
#                                                     ar  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   2  ON,Launcher,Messaging,Launcher,TVVideo_Apps,La...
#   3  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   4  ON,Launcher,Social_Networks,Launcher,Settings,...
#
#                                       gru4rec_Reminder  \
#   0  ON,Betting_Risk,Launcher,Betting_Risk,Launcher...
#   1          ON,Camera,VIDEO,Launcher,ON,Messaging,OFF
#   2  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   3  ON,Messaging,Social_Networks,Messaging,Launche...
#   4  ON,Music_Audio_Radio,Launcher,Social_Networks,...
#
#                                                gru4rec  \
#   0  ON,Betting_Risk,Launcher,Betting_Risk,Launcher...
#   1  ON,CONNECTED,Messaging,Launcher,Social_Network...
#   2  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   3       ON,Shopping,Messaging,Launcher,Messaging,OFF
#   4  ON,Messaging,Launcher,Messaging,Launcher,Inter...
#
#                                               hgru4rec  \
#   0  ON,Music_Audio_Radio,ON,Launcher,TVVideo_Apps,...
#   1  ON,Betting_Risk,Launcher,Betting_Risk,Launcher...
#   2  ON,Music_Audio_Radio,ON,Launcher,Social_Networ...
#   3  ON,Music_Audio_Radio,Launcher,Social_Networks,...
#   4  ON,CONNECTED,Camera,ON,Launcher,Music_Audio_Ra...
#
#                                                   shan  \
#   0  ON,Gaming_Simulation,Launcher,Messaging,Launch...
#   1  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   2  ON,Orientation,ON,Launcher,Timer_Clocks,Launch...
#   3  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#   4          ON,Camera,VIDEO,Launcher,ON,Messaging,OFF
#
#                                                   sknn  \
#   0          ON,Camera,VIDEO,Launcher,ON,Messaging,OFF
#   1  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   2  ON,Betting_Risk,Launcher,Betting_Risk,Launcher...
#   3  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   4  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#
#                                                  sr_BR  \
#   0  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   1  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   2  ON,Launcher,Messaging,Launcher,TVVideo_Apps,La...
#   3  ON,Betting_Risk,Launcher,Betting_Risk,Launcher...
#   4  ON,Launcher,Timer_Clocks,Launcher,Shop_Sell_Re...
#
#                                                     sr  \
#   0  ON,Betting_Risk,Launcher,Betting_Risk,Launcher...
#   1  ON,Internet_Browser,ON,Launcher,Internet_Brows...
#   2  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   3  ON,Launcher,Messaging,Launcher,TVVideo_Apps,La...
#   4  ON,Launcher,Messaging,Launcher,Social_Networks...
#
#                                                stan_ER  \
#   0          ON,Camera,VIDEO,Launcher,ON,Messaging,OFF
#   1  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   2  ON,Launcher,Messaging,Launcher,TVVideo_Apps,La...
#   3  ON,Gaming_Simulation,Launcher,Messaging,Launch...
#   4  ON,Launcher,Timer_Clocks,Launcher,Shop_Sell_Re...
#
#                                                   stan  \
#   0          ON,Camera,VIDEO,Launcher,ON,Messaging,OFF
#   1  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   2  ON,Betting_Risk,Launcher,Betting_Risk,Launcher...
#   3  ON,Launcher,ON,Messaging,Launcher,Social_Netwo...
#   4  ON,Messaging,Launcher,Messaging,Launcher,Messa...
#
#                                              vsknn_EBR  \
#   0          ON,Camera,VIDEO,Launcher,ON,Messaging,OFF
#   1  ON,Betting_Risk,Launcher,Betting_Risk,Launcher...
#   2  ON,Calendar_Apps,ON,Launcher,Music_Audio_Radio...
#   3  ON,Launcher,Internet_Browser,Sharing_Cloud,Int...
#   4  ON,Gaming_Simulation,Launcher,Messaging,Launch...
#
#                                                  vsknn  \
#   0          ON,Camera,VIDEO,Launcher,ON,Messaging,OFF
#   1  ON,Messaging,Launcher,Calling,Launcher,Messagi...
#   2  ON,Messaging,ON,Messaging,Internet_Browser,Lau...
#   3   ON,PLAY,PAUSE,Music_Audio_Radio,ON,Messaging,OFF
#   4             ON,Shared_Transportation,Education,OFF
#
#                                              vstan_EBR  \
#   0          ON,Camera,VIDEO,Launcher,ON,Messaging,OFF
#   1  ON,Launcher,Timer_Clocks,Launcher,Shop_Sell_Re...
#   2  ON,Launcher,ON,Messaging,Launcher,Messaging,La...
#   3  ON,Launcher,Messaging,Launcher,TVVideo_Apps,La...
#   4  ON,Calendar_Apps,ON,Launcher,Music_Audio_Radio...
#
#                                                  vstan
#   0          ON,Camera,VIDEO,Launcher,ON,Messaging,OFF
#   1  ON,Launcher,Orientation,Launcher,Financial,Lau...
#   2  ON,Betting_Risk,Launcher,Betting_Risk,Launcher...
#   3  ON,Launcher,Social_Networks,Launcher,Settings,...
#   4  ON,Internet_Browser,ON,Launcher,Internet_Brows...  )}

# %%
# predictions.apply(lambda x: x['recs-sr_B'][0] == x['ground_truth'], axis=1).sum()/len(predictions)

# %% [markdown]
# ### performance by position

# %% [markdown]
# We expect performance of neural algorithms to increase as the position increases. Since this is sequence-level analysis, there are plenty of long sentences.

# %%
algorithms = [i for i in predictions.columns if i.startswith('recs-')]

# %%
# helper function outputting whether ground truth is in recommendation list of length k for a single algorithm and item
def calc_hr_k(ground_truth, rec_list, k):
    return ground_truth in rec_list[:k]

# %%
pos_counts = predictions['position'].value_counts()

# %%
k=10

# %%
perf_by_pos = pd.DataFrame()
for pos in pos_counts.index:
    pred_pos = predictions[predictions['position']==pos]
    df = pd.DataFrame()
    df['position'] = [pos]
    count = pos_counts[pos]
    df['count'] = [count]
    for algo in algorithms:
        algo_name = ''.join(algo.split('-')[1:])
        value = pred_pos.apply(lambda x: calc_hr_k(x['ground_truth'], x[algo], k), axis=1).sum()/len(pred_pos)
        df[algo_name] = [value]
    perf_by_pos = perf_by_pos.append(df).reset_index(drop=True)

# %%
perf_by_pos.head(20)
# Out:
#     position  count        ar  gru4rec_Reminder   gru4rec  hgru4rec      shan  \
# 0          0    277  0.490975          0.418773  0.314079  0.223827  0.440433
# 1          1    262  0.461832          0.370229  0.251908  0.183206  0.408397
# 2          2    249  0.502008          0.437751  0.317269  0.188755  0.433735
# 3          3    241  0.514523          0.448133  0.331950  0.199170  0.402490
# 4          4    232  0.538793          0.413793  0.323276  0.206897  0.413793
# 5          5    226  0.526549          0.438053  0.340708  0.185841  0.438053
# 6          6    220  0.500000          0.490909  0.322727  0.200000  0.413636
# 7          7    214  0.495327          0.476636  0.383178  0.280374  0.350467
# 8          8    209  0.502392          0.397129  0.315789  0.167464  0.411483
# 9          9    203  0.541872          0.517241  0.384236  0.270936  0.389163
# 10        10    200  0.560000          0.510000  0.365000  0.245000  0.455000
# 11        11    193  0.585492          0.549223  0.404145  0.253886  0.461140
# 12        12    183  0.513661          0.480874  0.371585  0.284153  0.448087
# 13        13    177  0.480226          0.536723  0.401130  0.271186  0.367232
# 14        14    167  0.592814          0.526946  0.371257  0.239521  0.497006
# 15        15    163  0.576687          0.527607  0.355828  0.233129  0.392638
# 16        16    160  0.556250          0.531250  0.375000  0.281250  0.412500
# 17        17    155  0.574194          0.516129  0.400000  0.270968  0.451613
# 18        18    151  0.576159          0.529801  0.417219  0.258278  0.430464
# 19        19    149  0.496644          0.489933  0.369128  0.248322  0.369128
#
#         sknn     sr_BR        sr   stan_ER      stan  vsknn_EBR     vsknn  \
# 0   0.519856  0.534296  0.509025  0.501805  0.480144   0.364621  0.129964
# 1   0.450382  0.469466  0.469466  0.477099  0.473282   0.293893  0.137405
# 2   0.530120  0.510040  0.530120  0.522088  0.538153   0.281124  0.176707
# 3   0.502075  0.526971  0.510373  0.510373  0.506224   0.253112  0.149378
# 4   0.491379  0.504310  0.551724  0.512931  0.504310   0.262931  0.150862
# 5   0.539823  0.530973  0.522124  0.530973  0.530973   0.243363  0.154867
# 6   0.513636  0.513636  0.545455  0.486364  0.504545   0.254545  0.154545
# 7   0.481308  0.518692  0.556075  0.462617  0.500000   0.228972  0.149533
# 8   0.497608  0.497608  0.526316  0.507177  0.483254   0.263158  0.148325
# 9   0.522167  0.532020  0.556650  0.536946  0.541872   0.280788  0.182266
# 10  0.535000  0.530000  0.590000  0.520000  0.570000   0.305000  0.160000
# 11  0.544041  0.611399  0.595855  0.590674  0.580311   0.259067  0.150259
# 12  0.513661  0.546448  0.546448  0.546448  0.519126   0.289617  0.163934
# 13  0.463277  0.457627  0.531073  0.418079  0.491525   0.203390  0.180791
# 14  0.616766  0.616766  0.634731  0.556886  0.616766   0.251497  0.137725
# 15  0.576687  0.570552  0.607362  0.552147  0.601227   0.196319  0.153374
# 16  0.481250  0.587500  0.575000  0.575000  0.512500   0.275000  0.131250
# 17  0.548387  0.561290  0.580645  0.529032  0.587097   0.238710  0.154839
# 18  0.536424  0.582781  0.629139  0.609272  0.556291   0.284768  0.198675
# 19  0.456376  0.510067  0.557047  0.476510  0.536913   0.241611  0.174497
#
#     vstan_EBR     vstan
# 0    0.292419  0.487365
# 1    0.282443  0.480916
# 2    0.289157  0.554217
# 3    0.269710  0.510373
# 4    0.232759  0.525862
# 5    0.221239  0.535398
# 6    0.190909  0.518182
# 7    0.224299  0.495327
# 8    0.229665  0.497608
# 9    0.275862  0.541872
# 10   0.235000  0.585000
# 11   0.243523  0.595855
# 12   0.234973  0.540984
# 13   0.146893  0.474576
# 14   0.173653  0.634731
# 15   0.177914  0.588957
# 16   0.262500  0.512500
# 17   0.225806  0.567742
# 18   0.245033  0.589404
# 19   0.248322  0.516779

# %%
# considering only positions <= vs. >
perf_by_pos = pd.DataFrame()
cutoff = 5
for pos in ['<=', '>']:
    if pos=='<=':
        pred_pos = predictions[predictions['position']<=cutoff]
    else:
        pred_pos = predictions[predictions['position']>cutoff]
    df = pd.DataFrame()
    df['position'] = [pos]
    for algo in algorithms:
        algo_name = ''.join(algo.split('-')[1:])
        value = pred_pos.apply(lambda x: calc_hr_k(x['ground_truth'], x[algo], k), axis=1).sum()/len(pred_pos)
        df[algo_name] = [value]
    perf_by_pos = perf_by_pos.append(df).reset_index(drop=True)

# %%
perf_by_pos
# Out:
#   position        ar  gru4rec_Reminder   gru4rec  hgru4rec      shan  \
# 0       <=  0.504371          0.420309  0.312038  0.198386  0.422999
# 1        >  0.569509          0.537492  0.403616  0.258792  0.448905
#
#        sknn     sr_BR        sr   stan_ER      stan  vsknn_EBR     vsknn  \
# 0  0.505044  0.512441  0.514459  0.508406  0.504371   0.285810  0.149294
# 1  0.541971  0.567518  0.599536  0.559721  0.566025   0.260783  0.151792
#
#    vstan_EBR     vstan
# 0   0.266308  0.514459
# 1   0.229098  0.576808
