# %%
# import packages
import datetime
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import colors as mcolors
import numpy as np
import pandas as pd
import pyreadr
import os
import pickle5 as pickle
import h5py

from sklearn.manifold import TSNE
from sklearn.metrics.pairwise import cosine_similarity as cosine

# %%
max(data.date)
# Out:
# Timestamp('2018-01-22 22:58:55.812000036')

# %%
# create/load app and category mapping
data = pyreadr.read_r('../../data/sequences_all_anon.Rds')[None]
data.rename(columns={'datum':'date', 'value':'category', 'anon_apps.name':'app_name'}, inplace=True)
data['timestamp'] = data['date'].apply(lambda x: x.timestamp())
data.loc[data['app_name'].isnull(),'app_name'] = data['category'] # replace NaNs in app_name by corresponding category value
data['sessionID'] = data['app_name'].shift(1).isin(['OFF_LOCKED','OFF_UNLOCKED']).cumsum() + 1 # sessionID is like sequence_number but does NOT start anew for each user

app_mapping = dict([(y,x+1) for x,y in enumerate(sorted(set(data['app_name'])))])
app_mapping_reverse = dict((v,k) for k,v in app_mapping.items())

with open('../../data/app-level/category_mapping.pickle', 'rb') as handle:
    category_mapping = pickle.load(handle)

# %%
path = '../results/app-level/multiple/drop_on-drop_off/gru4rec_embedding/window_1_embeddings/'

# %%
with h5py.File(path + os.listdir(path)[0], 'r') as hf:
    embeddings = hf['embeddings'][:]
    indexes = hf['indexes'][:]

# %%
# TSNE
tsne = TSNE(random_state=1, n_iter=1000, metric="cosine")
embs = tsne.fit_transform(embeddings)

# %%
# helper function returning index of most similar app i.t.o. cosine similarity of app embedding
def max_cos_sim(x, ys, ignore=[]):
    max_cos = 0
    max_y = None
    max_i = None
    for i in range(len(ys)):
        y = ys[i]
        cos = cosine(x.reshape(1,-1), y.reshape(1,-1))
        if cos > max_cos:
            if not np.array_equal(x, y) and i not in ignore:
                max_cos = cos
                max_y = y
                max_i = i
#     return (max_cos, max_y, max_i)
    return max_i

# %%
# putting all embedding info together
df = pd.DataFrame()
df['embedding'] = embeddings.tolist()
df['embedding'] = df['embedding'].apply(lambda x: np.array(x))
df['x'] = embs[:, 0]
df['y'] = embs[:, 1]
df['appID'] = indexes
df['app_name'] = df['appID'].apply(lambda x: app_mapping_reverse[x])
df['app_category'] = df['app_name'].apply(lambda x: category_mapping[x])
df['max_similarity_id'] = df['embedding'].apply(lambda x: max_cos_sim(x, df['embedding']))
df['max_similarity_cat'] = df['max_similarity_id'].apply(lambda x: df['app_category'].iloc[x])

# %% [markdown]
# ### embedding visualization (TSNE)

# %%
# plot of app categories using reduced 2D app embeddings
colors = {'Messaging':'red', 'Social_Networks':'green', 'Tools':'blue'}
c = df['app_category'].map(colors).replace(np.nan, 'grey', regex=True)

FS = (10, 8)
fig, ax = plt.subplots(figsize=FS)

ax.scatter(embs[:, 0], embs[:, 1], alpha=.5, c=c)

plt.show

# label = 'Messaging'
# df.loc[df['app_name'].apply(lambda x: x.startswith(label)), 'labels'] = label
# df['labels'].replace(np.nan, '', regex=True, inplace=True)
# FS = (10, 8)
# fig, ax = plt.subplots(figsize=FS)
# ax.scatter(embs[:, 0], embs[:, 1], alpha=.1)
# for i, label in enumerate(df['labels']):
#     plt.annotate(label, (df['x'][i], df['y'][i]))
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
apps_by_freq = [x for x in data.app_name.value_counts().index if x in set(df.app_name)]

# %%
all_colors = dict(mcolors.BASE_COLORS, **mcolors.CSS4_COLORS)

# %%
# assign colors to k most frequent apps
k = 10

all_colors = dict(mcolors.BASE_COLORS, **mcolors.CSS4_COLORS)
colors = {}
for i in range(k):
    colors[apps_by_freq[i]] = list(all_colors.keys())[i]

c = df['app_name'].map(colors).replace(np.nan, 'lightgrey', regex=True)

# %%
# plot of k most frequent apps
FS = (10, 8)
fig, ax = plt.subplots(figsize=FS)

ax.scatter(embs[:, 0], embs[:, 1], alpha=1, c=c)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# plot with names of k most frequent apps
mask = df['app_name'].isin(apps_by_freq[:k])
df['labels'] = df['app_name'][mask]
df['labels'].replace(np.nan, '', regex=True, inplace=True)
FS = (10, 8)
fig, ax = plt.subplots(figsize=FS)
ax.scatter(embs[:, 0], embs[:, 1], alpha=.1)
for i, label in enumerate(df['labels']):
    plt.annotate(label, (df['x'][i], df['y'][i]))

# %% [markdown]
# ### embedding clustering (k-means)

# %%
# k-means for original embedding data
from sklearn.cluster import KMeans
km = KMeans(
    n_clusters=15, init='random',
    n_init=100, max_iter=500, 
    tol=1e-04, random_state=1
)

k_m = km.fit_predict(embeddings)
df['k_m'] = k_m

# %%
colors = {
    0: 'purple',
    1: 'red',
    2: 'green',
    3: 'blue',
    4: 'yellow',
    5: 'black',
    6: 'white',
    7: 'grey',
    8: 'orange',
    9: 'aqua',
    10: 'brown',
    11: 'lightgrey',
    12: 'darkgreen',
    13: 'pink',
    14: 'moccasin'
}

c = df['k_m'].map(colors)

# %%
# 2D visual illustration of clusters
FS = (10, 8)
fig, ax = plt.subplots(figsize=FS)
ax.scatter(embs[:, 0], embs[:, 1], alpha=.5, c=c)

# %%
for i in range(15):
    res = df.loc[df.k_m == i].app_category.value_counts()
    print(i)
    print(res)
# Out:
# 0
# Camera                     18
# Image_And_Video_Editing     8
# Financial                   4
# System_App                  3
# Beauty                      3
# Gaming_Simulation           3
# Entertainment               3
# Tools                       3
# Gaming_Casual               3
# Launcher                    2
# Social_Networks             2
# TVVideo_Apps                2
# Orientation                 2
# Calculator                  2
# Messaging                   2
# Security                    2
# Language_Learning           2
# Gaming_Adventure            2
# Office_Tools                2
# Education                   2
# Emergency_Warning           1
# Personalization             1
# Shop_Sell_Rent              1
# News_Magazines              1
# Music_Audio_Radio           1
# Artistic_Hobby              1
# Social_Media_Tools          1
# Gallery                     1
# Note_Apps                   1
# Shared_Transportation       1
# ComicsBooks                 1
# Organisation                1
# Gaming_Action               1
# Gaming_Role_Playing         1
# Sport_News                  1
# Shopping                    1
# Weather                     1
# PHOTO                       1
# Name: app_category, dtype: int64
# 1
# Gaming_Casual              9
# Financial                  4
# Travel                     3
# Language_Learning          3
# Dating_Mating              3
# Eating                     3
# Artistic_Hobby             2
# Entertainment              2
# System_App                 2
# Gaming_Logic               2
# Security                   1
# Office_Tools               1
# Gaming_Strategy            1
# Orientation                1
# Image_And_Video_Editing    1
# Gaming_Action              1
# Public_Events              1
# Private_Transportation     1
# Launcher                   1
# Weather                    1
# Education                  1
# Tools                      1
# Social_Networks            1
# Name: app_category, dtype: int64
# 2
# Music_Audio_Radio        4
# Gaming_Logic             4
# Social_Networks          3
# Financial                3
# Tools                    3
# Gaming_Casual            3
# Shared_Transportation    2
# Gaming_Simulation        2
# Eating                   2
# Note_Apps                2
# Security                 2
# Dating_Mating            2
# Gaming_Action            2
# Timer_Clocks             2
# Education                2
# Group_Activity           1
# Health_SelfMonitoring    1
# Artistic_Hobby           1
# News_Magazines           1
# Academia                 1
# Gallery                  1
# Calculator               1
# Organisation             1
# Shop_Sell_Rent           1
# TVVideo_Apps             1
# Camera                   1
# System_App               1
# Entertainment            1
# Office_Tools             1
# Shopping                 1
# Launcher                 1
# Weather                  1
# Travel                   1
# Name: app_category, dtype: int64
# 3
# Music_Audio_Radio        2
# Financial                2
# Calendar_Apps            1
# Calculator               1
# Tools                    1
# Weather                  1
# Language_Learning        1
# Office_Tools             1
# Timer_Clocks             1
# Launcher                 1
# E_Mail                   1
# Shared_Transportation    1
# System_App               1
# Note_Apps                1
# Name: app_category, dtype: int64
# 4
# Gaming_Casual       13
# Tools               12
# System_App           9
# Security             9
# Gaming_Logic         8
#                     ..
# Workout              1
# VIDEO                1
# Personalization      1
# DISCONNECTED         1
# Internet_Browser     1
# Name: app_category, Length: 62, dtype: int64
# 5
# Tools                     8
# Music_Audio_Radio         7
# Sport_News                7
# Health_SelfMonitoring     6
# Financial                 6
# Shopping                  5
# Gaming_Casual             5
# TVVideo_Apps              4
# Security                  3
# Travel                    3
# Gaming_Logic              3
# Eating                    3
# Organisation              3
# Betting_Risk              3
# Workout                   3
# System_App                3
# News_Magazines            3
# Social_Networks           3
# Language_Learning         3
# Orientation               2
# Shared_Transportation     2
# Timer_Clocks              2
# Private_Transportation    2
# Gaming_Action             2
# Internet_Browser          2
# Weather                   2
# Office_Tools              2
# Gaming_Simulation         2
# Note_Apps                 2
# Entertainment             2
# Dating_Mating             1
# Calculator                1
# Gaming_Knowledge          1
# Provider_Services         1
# PLAY                      1
# Social_Media_Tools        1
# TV_Film_Guide             1
# ComicsBooks               1
# Calendar_Apps             1
# Messaging                 1
# E_Mail                    1
# Camera                    1
# Sharing_Cloud             1
# Group_Activity            1
# Public_Events             1
# Womens_Apps               1
# Calling                   1
# Personalization           1
# Gaming_Strategy           1
# Emergency_Warning         1
# Name: app_category, dtype: int64
# 6
# System_App                         20
# Tools                              17
# Financial                          14
# TVVideo_Apps                       12
# Shopping                           10
# Organisation                        9
# Entertainment                       7
# Social_Networks                     6
# Image_And_Video_Editing             6
# Office_Tools                        6
# Weather                             6
# Security                            6
# Music_Audio_Radio                   6
# Artistic_Hobby                      5
# Personalization                     5
# Checkup_Monitoring                  5
# Camera                              5
# E_Mail                              5
# Health_SelfMonitoring               5
# Sharing_Cloud                       4
# Note_Apps                           4
# Womens_Apps                         4
# Beauty                              4
# Shared_Transportation               4
# Messaging                           3
# Gaming_Logic                        3
# Timer_Clocks                        3
# Shop_Sell_Rent                      3
# Internet_Browser                    3
# Gaming_Strategy                     3
# Academia                            3
# Orientation                         3
# Language_Learning                   3
# Emergency_Warning                   2
# Provider_Services                   2
# Workout                             2
# Education                           2
# Social_Media_Tools                  2
# Sleep                               2
# News_Magazines                      2
# Gaming_Tools_Community              2
# Settings                            2
# Calling                             2
# Eating                              2
# Calendar_Apps                       2
# Public_Events                       2
# Calculator                          2
# Fake_Apps                           2
# Dating_Mating                       1
# Jobs_Additional_Income              1
# Gaming_Casual                       1
# TV_Film_Guide                       1
# Gaming_Action                       1
# CONNECTED                           1
# ComicsBooks                         1
# Religion_Spirituality_Esotersim     1
# Gallery                             1
# Programming_Tools                   1
# Gaming_Simulation                   1
# Name: app_category, dtype: int64
# 7
# Tools                      13
# Gaming_Casual              12
# Image_And_Video_Editing     7
# Calling                     7
# Shopping                    6
# Shared_Transportation       5
# Travel                      5
# Music_Audio_Radio           4
# Security                    4
# Gaming_Adventure            4
# Camera                      4
# Office_Tools                3
# Entertainment               3
# Financial                   3
# System_App                  3
# Activism_Charity            2
# Gaming_Knowledge            2
# Gaming_Logic                2
# Gaming_Action               2
# Group_Activity              2
# Gaming_Role_Playing         1
# Personalization             1
# Workout                     1
# Calculator                  1
# Checkup_Monitoring          1
# News_Magazines              1
# E_Mail                      1
# Internet_Browser            1
# Language_Learning           1
# Education                   1
# Womens_Apps                 1
# Dating_Mating               1
# Academia                    1
# Public_Events               1
# Emergency_Warning           1
# ComicsBooks                 1
# Social_Networks             1
# Gaming_Sports               1
# TVVideo_Apps                1
# Eating                      1
# Social_Media_Tools          1
# Gaming_Simulation           1
# Name: app_category, dtype: int64
# 8
# System_App                16
# Tools                     12
# Music_Audio_Radio          8
# Checkup_Monitoring         7
# Personalization            7
# Security                   5
# Provider_Services          4
# Sharing_Cloud              3
# Settings                   3
# Health_SelfMonitoring      3
# Organisation               2
# Gaming_Tools_Community     2
# Shopping                   2
# Eating                     1
# Financial                  1
# Gaming_Casual              1
# SHUTDOWN                   1
# Office_Tools               1
# Emergency_Warning          1
# Camera                     1
# Sports                     1
# Timer_Clocks               1
# Calling                    1
# Gaming_Action              1
# Entertainment              1
# Private_Transportation     1
# Sport_News                 1
# Beauty                     1
# Language_Learning          1
# Education                  1
# Name: app_category, dtype: int64
# 9
# Financial                          19
# Gaming_Casual                      15
# Music_Audio_Radio                  12
# News_Magazines                     11
# Gaming_Logic                       11
# Shopping                           10
# Tools                               9
# TVVideo_Apps                        9
# Language_Learning                   8
# Organisation                        8
# Messaging                           7
# Weather                             7
# Gaming_Strategy                     7
# Academia                            7
# Sport_News                          7
# ComicsBooks                         6
# TV_Film_Guide                       6
# Health_SelfMonitoring               6
# System_App                          5
# Eating                              5
# Entertainment                       5
# Shared_Transportation               5
# Gaming_Role_Playing                 5
# Office_Tools                        5
# E_Mail                              4
# Timer_Clocks                        4
# Calling                             4
# Provider_Services                   4
# Calendar_Apps                       4
# Checkup_Monitoring                  4
# Education                           4
# Shop_Sell_Rent                      4
# Travel                              4
# Orientation                         3
# Religion_Spirituality_Esotersim     3
# Gaming_Sports                       3
# Social_Networks                     3
# Calculator                          3
# Social_Media_Tools                  3
# Gaming_Action                       3
# Internet_Browser                    3
# Private_Transportation              2
# Sleep                               2
# Sharing_Cloud                       2
# Womens_Apps                         2
# Gaming_Simulation                   2
# Sports                              2
# Note_Apps                           2
# Gaming_Knowledge                    2
# Betting_Risk                        1
# Gallery                             1
# Gaming_Tools_Community              1
# Security                            1
# Workout                             1
# Image_And_Video_Editing             1
# Camera                              1
# Personalization                     1
# Dating_Mating                       1
# Jobs_Additional_Income              1
# Emergency_Warning                   1
# Name: app_category, dtype: int64
# 10
# Music_Audio_Radio                  5
# News_Magazines                     5
# Sport_News                         4
# System_App                         4
# Shared_Transportation              4
# Womens_Apps                        3
# Health_SelfMonitoring              3
# Office_Tools                       3
# E_Mail                             3
# Eating                             3
# Messaging                          3
# Camera                             2
# Gaming_Casual                      2
# Image_And_Video_Editing            2
# Sports                             2
# Provider_Services                  2
# Gaming_Simulation                  2
# Social_Networks                    2
# Weather                            2
# Language_Learning                  2
# Calling                            2
# Note_Apps                          1
# Security                           1
# Organisation                       1
# Gallery                            1
# Internet_Browser                   1
# Religion_Spirituality_Esotersim    1
# TVVideo_Apps                       1
# Timer_Clocks                       1
# Calendar_Apps                      1
# Entertainment                      1
# Orientation                        1
# Gaming_Logic                       1
# Betting_Risk                       1
# Financial                          1
# Personalization                    1
# Academia                           1
# Gaming_Action                      1
# Dating_Mating                      1
# Name: app_category, dtype: int64
# 11
# Launcher                   16
# System_App                  6
# Gaming_Casual               4
# Gallery                     4
# Health_SelfMonitoring       3
# Music_Audio_Radio           2
# Financial                   2
# Organisation                2
# News_Magazines              2
# Image_And_Video_Editing     2
# Personalization             2
# Language_Learning           2
# Note_Apps                   2
# Messaging                   2
# ComicsBooks                 2
# Education                   2
# Tools                       2
# Timer_Clocks                2
# Shopping                    1
# Gaming_Knowledge            1
# Calendar_Apps               1
# Calculator                  1
# Internet_Browser            1
# Security                    1
# Gaming_Strategy             1
# Calling                     1
# Shared_Transportation       1
# Gaming_Action               1
# Sport_News                  1
# Womens_Apps                 1
# Settings                    1
# Checkup_Monitoring          1
# Sports                      1
# TVVideo_Apps                1
# Entertainment               1
# Travel                      1
# Office_Tools                1
# Name: app_category, dtype: int64
# 12
# Organisation               7
# Tools                      6
# Music_Audio_Radio          5
# Security                   5
# Shared_Transportation      4
# Calling                    4
# Shopping                   4
# Sport_News                 4
# Gallery                    4
# Gaming_Casual              3
# Internet_Browser           3
# Health_SelfMonitoring      3
# Language_Learning          3
# Note_Apps                  3
# Messaging                  3
# Gaming_Logic               3
# Eating                     3
# Weather                    3
# Calendar_Apps              3
# Office_Tools               2
# Launcher                   2
# Orientation                2
# News_Magazines             2
# Social_Media_Tools         2
# Financial                  2
# Gaming_Role_Playing        2
# Personalization            2
# Gaming_Knowledge           2
# Image_And_Video_Editing    1
# Gaming_Tools_Community     1
# OUTBOX                     1
# E_Mail                     1
# Emergency_Warning          1
# TVVideo_Apps               1
# ComicsBooks                1
# Calculator                 1
# Education                  1
# Social_Networks            1
# Timer_Clocks               1
# Private_Transportation     1
# Shop_Sell_Rent             1
# Activism_Charity           1
# Entertainment              1
# Camera                     1
# Sharing_Cloud              1
# Provider_Services          1
# Name: app_category, dtype: int64
# 13
# Tools                     12
# Shared_Transportation      5
# Organisation               5
# Social_Networks            5
# Health_SelfMonitoring      4
# E_Mail                     4
# Internet_Browser           3
# News_Magazines             3
# Personalization            2
# Gaming_Casual              2
# Messaging                  2
# Music_Audio_Radio          2
# Education                  2
# Financial                  2
# Timer_Clocks               2
# Shopping                   2
# Calling                    2
# Academia                   2
# Weather                    1
# Calendar_Apps              1
# Checkup_Monitoring         1
# Jobs_Additional_Income     1
# Emergency_Warning          1
# Security                   1
# Provider_Services          1
# Orientation                1
# Activism_Charity           1
# Social_Media_Tools         1
# Note_Apps                  1
# Workout                    1
# System_App                 1
# Sharing_Cloud              1
# Office_Tools               1
# Sport_News                 1
# Launcher                   1
# Gallery                    1
# Gaming_Logic               1
# Name: app_category, dtype: int64
# 14
# Gaming_Casual              23
# Gaming_Logic               10
# TVVideo_Apps                7
# Financial                   7
# Shopping                    6
# Social_Networks             5
# Tools                       5
# Gaming_Simulation           5
# Entertainment               4
# System_App                  4
# Music_Audio_Radio           4
# Gaming_Strategy             3
# Image_And_Video_Editing     3
# Education                   3
# Orientation                 2
# Health_SelfMonitoring       2
# Workout                     2
# Gallery                     2
# Gaming_Knowledge            2
# Travel                      2
# Gaming_Role_Playing         2
# Gaming_Adventure            2
# Eating                      2
# Sleep                       2
# Sport_News                  2
# Gaming_Action               2
# REJECTED                    1
# RINGING                     1
# Gaming_Tools_Community      1
# Security                    1
# Launcher                    1
# Public_Events               1
# OUTGOING                    1
# Language_Learning           1
# Shop_Sell_Rent              1
# Office_Tools                1
# Provider_Services           1
# Timer_Clocks                1
# Calendar_Apps               1
# Organisation                1
# INCOMING                    1
# Messaging                   1
# MISSED                      1
# ONHOLD                      1
# Dating_Mating               1
# TV_Film_Guide               1
# Jobs_Additional_Income      1
# Sports                      1
# Name: app_category, dtype: int64

# %%
df.groupby(['k_m'])['app_category'].value_counts()[:50]
# Out:
# k_m  app_category
# 0    Camera                     18
#      Image_And_Video_Editing     8
#      Financial                   4
#      Beauty                      3
#      Entertainment               3
#      Gaming_Casual               3
#      Gaming_Simulation           3
#      System_App                  3
#      Tools                       3
#      Calculator                  2
#      Education                   2
#      Gaming_Adventure            2
#      Language_Learning           2
#      Launcher                    2
#      Messaging                   2
#      Office_Tools                2
#      Orientation                 2
#      Security                    2
#      Social_Networks             2
#      TVVideo_Apps                2
#      Artistic_Hobby              1
#      ComicsBooks                 1
#      Emergency_Warning           1
#      Gallery                     1
#      Gaming_Action               1
#      Gaming_Role_Playing         1
#      Music_Audio_Radio           1
#      News_Magazines              1
#      Note_Apps                   1
#      Organisation                1
#      PHOTO                       1
#      Personalization             1
#      Shared_Transportation       1
#      Shop_Sell_Rent              1
#      Shopping                    1
#      Social_Media_Tools          1
#      Sport_News                  1
#      Weather                     1
# 1    Gaming_Casual               9
#      Financial                   4
#      Dating_Mating               3
#      Eating                      3
#      Language_Learning           3
#      Travel                      3
#      Artistic_Hobby              2
#      Entertainment               2
#      Gaming_Logic                2
#      System_App                  2
#      Education                   1
#      Gaming_Action               1
# Name: app_category, dtype: int64

# %% [markdown]
# ### app similarity and analogy

# %%
# percentage of apps whose category coincides with category of most similar app
sum(df['max_similarity_cat'] == df['app_category'])/df.shape[0]
# Out:
# 0.10957324106113034

# %% [markdown]
# ##### analogy

# %%
# analogy = ['Messaging_1', 'Social_Networks_1', 'Social_Networks_2']
# analogy = ['Messaging_1', 'Launcher_1', 'Launcher_22']
# analogy = ['Messaging_1', 'Internet_Browser_1', 'Internet_Browser_2']
# analogy = ['Launcher_1', 'Social_Networks_1', 'Social_Networks_2']
# analogy = ['Messaging_1', 'Music_Audio_Radio_1', 'Messaging_10']
# analogy = ['Social_Networks_1', 'Social_Networks_2', 'Social_Networks_4']
# analogy = ['Messaging_1', 'Messaging_2', 'Messaging_3']
# analogy = ['Internet_Browser_1', 'Internet_Browser_2', 'Internet_Browser_3']
# analogy = ['Orientation_1', 'Messaging_1', 'Messaging_2']
analogy = ['Messaging_1', 'Calling_27', 'Calling_35']

# %%
ignore = [df.loc[df['app_name'] == a].index.values.astype(int)[0] for a in analogy]

# %%
x = df['embedding'][ignore[0]] - df['embedding'][ignore[1]] + df['embedding'][ignore[2]]
ys = df['embedding']
ind = max_cos_sim(x, ys, ignore=ignore)
print(df['app_category'][ind])
# Out:
# Personalization
